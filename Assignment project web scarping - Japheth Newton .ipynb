# %% [markdown]
#                                  Assignment project web scarping - Japheth Newton

# %%
                             #Website : Quotes to Scrap : http://quotes.toscrape.com/page/1/'

# %%
           #To perform web scraping in Python, you can use libraries such as BeautifulSoup,Request and pandas

#libries are imported
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Retrieve the HTML: Use a library like requests to send an HTTP request to the website and retrieve the HTML content of the page
url = 'http://quotes.toscrape.com/page/1/'
response = requests.get(url)

# %%
r = response.content

# %%
#Parse the HTML: Use the web scraping library (e.g., BeautifulSoup) to parse the HTML content and create a parse tree that represents the structure of the web page
soup = BeautifulSoup(r, 'html.parser')

# %%
#Find Elements: Use the library's methods or functions to find specific HTML elements that contain the data you want to extract
El= soup.find("div")

# %%
quotes = El.find_all("div",class_ ="quote" )

# %%
#Extract Data: Once you've located the desired elements, use the library's methods to extract the relevant data. 
#This could involve accessing attributes, retrieving text and content.

# %%
for div in quotes:
    quote = div.find("span").text[1:-1]
    print(quote)
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
# It is our choices, Harry, that show what we truly are, far more than our abilities.
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
# Try not to become a man of success. Rather become a man of value.
# It is better to be hated for what you are than to be loved for what you are not.
# I have not failed. I've just found 10,000 ways that won't work.
# A woman is like a tea bag; you never know how strong it is until it's in hot water.
# A day without sunshine is like, you know, night.

# %%
for div in quotes:
    author = div.find("small").text
    print(author)
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %%
for div in quotes:
    tags = div.find("meta")
    tags_1 = tags.attrs["content"]
    print(tags_1)
# Out:
# change,deep-thoughts,thinking,world
# abilities,choices
# inspirational,life,live,miracle,miracles
# aliteracy,books,classic,humor
# be-yourself,inspirational
# adulthood,success,value
# life,love
# edison,failure,inspirational,paraphrased
# misattributed-eleanor-roosevelt
# humor,obvious,simile

# %%
for div in quotes:
    top_10_tags = div.find("a" , class_ = "tag")
    top_10 = top_10_tags.attrs["href"][5:-8]
    print(top_10)
# Out:
# change
# abilities
# inspirational
# aliteracy
# be-yourself
# adulthood
# life
# edison
# misattributed-eleanor-roosevelt
# humor

# %%
Quotes = []

for i in range(1,5):
    url = 'http://quotes.toscrape.com/page/1/'
    response = requests.get(url)
    r
    soup = BeautifulSoup(r, 'html.parser')
    El= soup.find("div")
    quotes = El.find_all("div",class_ ="quote" )
    
    for div in quotes:
        quote = div.find("span").text[1:-1]
        author = div.find("small").text
        tags = div.find("meta")
        tags_1 = tags.attrs["content"]
        top_10_tags = div.find("a" , class_ = "tag")
        top_10 = top_10_tags.attrs["href"][5:-8]
        Quotes.append([quote,author,tags_1,top_10])

# %%
#Data Processing and Storage: Perform any necessary data processing or cleaning on the extracted data. Then, store the data in a suitable format, such as CSV, Excel, or a database, 
#based on your requirements.

# %%
new_file = pd.DataFrame(Quotes,columns = ["Quotes","Author","Tags","Top_10_tags"])

# %%
new_file.head(39)
# Out:
#                                                Quotes             Author  \
# 0   The world as we have created it is a process o...    Albert Einstein
# 1   It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2   There are only two ways to live your life. One...    Albert Einstein
# 3   The person, be it gentleman or lady, who has n...        Jane Austen
# 4   Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5   Try not to become a man of success. Rather bec...    Albert Einstein
# 6   It is better to be hated for what you are than...         André Gide
# 7   I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8   A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9    A day without sunshine is like, you know, night.       Steve Martin
# 10  The world as we have created it is a process o...    Albert Einstein
# 11  It is our choices, Harry, that show what we tr...       J.K. Rowling
# ...

# %%
new_file.to_csv("Assignment project web scarping - Japheth Newton.csv", index=False)

# %%
#Respect Website Policies and Ethics: When scraping websites, make sure to comply with the website's terms of service, robots.txt file, and any other relevant policies. Be mindful of the website's 
#bandwidth and avoid overloading the server with excessive requests.
